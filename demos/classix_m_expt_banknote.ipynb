# %%
import datasets
from classix import CLASSIX
from sklearn.cluster import KMeans, DBSCAN, HDBSCAN, OPTICS, AgglomerativeClustering, SpectralClustering, MeanShift
from sklearn.metrics import silhouette_score
from datasets import load_dataset
import ucimlrepo
from ucimlrepo import fetch_ucirepo
import numpy as np
import cv2 as cv
import time
import PIL
from PIL import Image
import umap
from matplotlib import pyplot as plt
from sklearn.metrics import adjusted_rand_score as ari

# %%
data = fetch_ucirepo(id=267)
data.data.features = data.data.features.dropna()
np.unique(np.array(data.data.targets).T[0])
x = np.array(data.data.features)
y = np.array(data.data.targets).T[0]
labels = y
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# -> 1336 self._send_request(method, url, body, headers, encode_chunked)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1382, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1381     body = _encode(body, 'body')
# -> 1382 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1035, in HTTPConnection.send(self, data)
#    1034 if self.auto_open:
# -> 1035     self.connect()
#    1036 else:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1470, in HTTPSConnection.connect(self)
#    1468 "Connect to a host on a given (SSL) port."
# -> 1470 super().connect()
#    1472 if self._tunnel_host:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1001, in HTTPConnection.connect(self)
#    1000 sys.audit("http.client.connect", self, self.host, self.port)
# -> 1001 self.sock = self._create_connection(
#    1002     (self.host,self.port), self.timeout, self.source_address)
#    1003 # Might fail in OSs that don't implement TCP_NODELAY
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:864, in create_connection(address, timeout, source_address, all_errors)
#     863 if not all_errors:
# --> 864     raise exceptions[0]
#     865 raise ExceptionGroup("create_connection failed", exceptions)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:849, in create_connection(address, timeout, source_address, all_errors)
#     848     sock.bind(source_address)
# --> 849 sock.connect(sa)
#     850 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# File ~/Desktop/classix_merge/classix/.venv/lib/python3.13/site-packages/ucimlrepo/fetch.py:68, in fetch_ucirepo(name, id)
#      67 try:
# ---> 68     response = urllib.request.urlopen(api_url, context=ssl.create_default_context(cafile=certifi.where()))
#      69     data = json.load(response)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:189, in urlopen(url, data, timeout, context)
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:489, in OpenerDirector.open(self, fullurl, data, timeout)
#     488 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 489 response = self._open(req, data)
#     491 # post-process response
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:506, in OpenerDirector._open(self, req, data)
#     505 protocol = req.type
# --> 506 result = self._call_chain(self.handle_open, protocol, protocol +
#     507                           '_open', req)
#     508 if result:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     465 func = getattr(handler, meth_name)
# --> 466 result = func(*args)
#     467 if result is not None:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:1367, in HTTPSHandler.https_open(self, req)
#    1366 def https_open(self, req):
# -> 1367     return self.do_open(http.client.HTTPSConnection, req,
#    1368                         context=self._context)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:1322, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1321 except OSError as err: # timeout error
# -> 1322     raise URLError(err)
#    1323 r = h.getresponse()
#
# URLError: <urlopen error [Errno 61] Connection refused>
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data = fetch_ucirepo(id=267)
#       2 data.data.features = data.data.features.dropna()
#       3 np.unique(np.array(data.data.targets).T[0])
#
# File ~/Desktop/classix_merge/classix/.venv/lib/python3.13/site-packages/ucimlrepo/fetch.py:71, in fetch_ucirepo(name, id)
#      69     data = json.load(response)
#      70 except (urllib.error.URLError, urllib.error.HTTPError):
# ---> 71     raise ConnectionError('Error connecting to server')
#      73 # verify that dataset exists
#      74 if data['status'] != 200:
#
# ConnectionError: Error connecting to server

# %%
x = umap.UMAP(n_components=2, metric='manhattan').fit_transform(x)
# Out:
# /Users/user/Desktop/classix_merge/classix/.venv/lib/python3.13/site-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(

# %%
clx_m = CLASSIX(metric="manhattan", radius=0.17, minPts=20, mergeScale=1.5)
st = time.time()
clx_m.fit(x)
print("time: ", time.time() - st)
plt.scatter(x[:, 0], x[:, 1], c=clx_m.labels_)
plt.show()
# plt.savefig("banknote.svg", format='svg')
plt.scatter(x[:, 0], x[:, 1], c=labels)
# plt.savefig("banknote_gt.svg", format='svg')
print("silhouette_score classix_m: ", silhouette_score(x, clx_m.labels_))
print("silhouette_score banknote_gt: ", silhouette_score(x, labels))
# Out:
# CLASSIX(radius=0.17, minPts=20, group_merging='distance')
# Aggregation:   0%|          | 0/1372 [00:00<?, ?it/s]
# Manhattan merging completed: 4 clusters
# time:  0.014662981033325195
# silhouette_score classix_m:  0.39834994077682495
# silhouette_score banknote_gt:  0.42882615327835083

# %%
db = DBSCAN(eps=0.5, min_samples=10, metric='manhattan')
st = time.time()
db.fit(x)
print("time: ", time.time() - st)
print("silhouette_score dbscan: ", silhouette_score(x, db.labels_))
plt.scatter(x[:, 0], x[:, 1], c=db.labels_)
plt.show()
# plt.savefig("banknote_db.svg", format='svg')
# Out:
# time:  0.027950286865234375
# silhouette_score dbscan:  0.5883893966674805

# %%
op = OPTICS(max_eps = 0.45, min_samples=10, metric='manhattan')
st = time.time()
op.fit(x)
print("silhouette_score optics: ", silhouette_score(x, op.labels_))
print("time: ", time.time() - st)
plt.scatter(x[:, 0], x[:, 1], c=op.labels_)
plt.show()
# plt.savefig("banknote_op.svg", format='svg')
# Out:
# silhouette_score optics:  0.37793663144111633
# time:  0.5862288475036621

# %%
print("ari classix_m: ", ari(labels, clx_m.labels_))
print("ari dbscan: ", ari(labels, db.labels_))
print("ari optics: ", ari(labels, op.labels_))
# Out:
# ari classix_m:  0.18370792402092254
# ari dbscan:  0.07831697191286054
# ari optics:  0.01665804857664394

# %%
plt.clf()
fig, axes = plt.subplots(2, 2, figsize=(12, 12))

axes[0,0].scatter(x[:, 0], x[:, 1], c=labels)
axes[0,0].set_title("banknote_gt")
axes[0,1].scatter(x[:, 0], x[:, 1], c=clx_m.labels_)
axes[0,1].set_title("banknote_classix_m")
axes[1,0].scatter(x[:, 0], x[:, 1], c=db.labels_)
axes[1,0].set_title("banknote_dbscan")
axes[1,1].scatter(x[:, 0], x[:, 1], c=op.labels_)
axes[1,1].set_title("banknote_optics")
plt.show()
# plt.savefig('banknote_all.svg', format='svg', bbox_inches='tight', dpi=300)
